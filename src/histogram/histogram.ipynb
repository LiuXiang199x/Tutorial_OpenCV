# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def plot_demo(image):
    # ravel()是降维，将多维将为一维
    # 统计为256个bin，然后范围是0-255
    plt.hist(image.ravel(),256,[0,256])
    plt.show()
    
def image_hist(image):
    # 先将图像的三个通道表示出来
    color = ["blue","green","red"]
    for i, color in enumerate(color):
        hist = cv.calcHist([image],[i],None,[256],[0,256])#不包含右值 
        plt.plot(hist, color=color)
        plt.xlim([0,256])
    plt.show()
    
print("-----------cv.python-----------")
src = cv.imread("/home/anaconda/桌面/自学OpenCV/src/image/lena.jpg")
cv.namedWindow("input image", cv.WINDOW_AUTOSIZE)
cv.imshow("original image", src)

image_hist(src)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# -----------cv.python-----------

# %%
a = (1,2,3)
color = ["red",'green','blue']
print(type(a))
print(type(color))
for i, color in enumerate(color):
    print(i)
    print(type(i))
    print(type(color))
    print(color)
# Out:
# <type 'tuple'>
# <type 'list'>
# 0
# <type 'int'>
# <type 'str'>
# red
# 1
# <type 'int'>
# <type 'str'>
# green
# 2
# <type 'int'>
# <type 'str'>
# blue
